# %%
class Dog:
    def __init__(self, name, gender, breed, age, weight, color):
        self.name = name
        self.gender = gender
        self.breed = breed
        self.age = age
        self.weight = weight
        self.color = color

    def showInfo(self):
        print("""
ชื่อ: {}
เพศ: {}
สายพันธุ์: {}
อายุ: {} 
น้ำหนัก: {}
สี: {}
        """.format(self.name, self.gender,self.breed, self.age,self.weight, self.color))

    def sit(self):
        print("{}")

    def eat(self, food):
        print("{}")

# %%
# Instance Variable / Object
dog_earn = Dog("Earn", "ผู้", "Husky", 4, 80, "ดำ")
dog_chol = Dog("Chol", "เมีย", "Labrador", 4, 120, "แดง")

# %%
่ม
